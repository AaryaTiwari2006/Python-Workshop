# %%
purse = dict()
purse['money'] = 12
purse['candy']= 3
purse['tissues'] = 75
print(purse)
print(purse['candy'])
purse['candy'] = purse['candy']+2
print(purse)
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}
# 3
# {'money': 12, 'candy': 5, 'tissues': 75}

# %%
fhand = open('abcd.txt')
print(fhand)
# Out:
# <_io.TextIOWrapper name='abcd.txt' mode='r' encoding='cp1252'>

# %%
xfile = open('abcd.txt')
for cheese in xfile:
    print(cheese)
# Out:
# hi my name is aarya tiwari
#
# jhinga lala hu hu

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy
from numpy import random

# %%
x = random.normal(size=1000)
x = random.normal(size=(2,3))
x = random.normal(loc=1, scale=2, size=(2,3))
print(x)
# Out:
# [[0.07717662 0.4879009  0.38659261]
#  [0.53834898 3.30451473 1.3975739 ]]

# %%
sns.distplot(random.normal(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\aarya\AppData\Local\Temp\ipykernel_17112\1308901639.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %%
sns.distplot(random.normal(size=1000), hist=True)
plt.show()
# Out:
# C:\Users\aarya\AppData\Local\Temp\ipykernel_17112\3190080908.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=True)

# %%
from numpy import random
x = random.binomial(n=10, p=0.5, size=1000)
print(x)
# Out:
# [6 5 3 4 4 5 4 6 5 7 7 3 5 4 3 6 7 5 1 5 6 8 7 4 3 7 2 4 6 3 6 3 9 7 4 5 4
#  4 4 4 4 2 6 5 3 8 2 5 3 6 6 6 3 4 4 4 5 5 7 5 2 3 7 7 8 3 4 8 5 4 6 6 5 7
#  4 5 7 5 4 5 6 2 6 3 6 2 7 7 5 7 2 3 8 6 4 7 7 5 6 6 4 6 4 5 2 7 2 5 4 7 3
#  3 8 5 4 5 3 7 4 4 6 5 6 5 0 3 6 3 6 5 5 5 7 4 7 6 3 7 6 8 5 5 1 6 3 5 7 6
#  5 5 6 4 7 5 4 6 5 5 5 9 3 6 3 6 5 5 5 4 5 6 7 8 6 5 7 8 6 3 5 5 6 9 6 3 3
#  6 6 3 6 3 2 3 2 8 6 3 6 6 3 5 7 9 6 7 5 3 7 5 8 4 4 2 5 7 4 6 7 6 6 8 7 5
#  7 6 6 8 5 5 3 5 6 3 6 6 6 6 3 4 4 5 6 6 7 7 9 5 6 7 8 2 4 2 3 7 7 7 4 3 5
#  3 7 8 3 2 6 6 5 3 6 7 5 4 5 3 7 5 6 6 5 5 4 7 7 6 4 5 2 6 8 5 5 4 5 6 3 5
#  6 4 5 7 2 5 6 5 5 6 7 8 6 4 6 5 3 5 8 5 7 4 2 5 4 6 5 3 9 5 3 4 6 6 4 4 6
#  5 4 2 5 8 5 4 6 6 6 6 2 7 3 5 7 4 5 6 5 4 6 2 7 6 4 5 4 7 6 7 4 5 7 5 8 6
#  5 3 5 4 5 9 3 5 5 3 7 7 5 5 5 5 7 5 3 6 6 6 6 5 5 4 5 6 6 6 5 4 7 6 8 7 9
#  6 4 5 5 8 5 5 3 6 6 7 4 4 6 5 6 5 3 4 4 4 5 3 5 4 6 3 6 5 5 5 6 6 6 6 5 3
#  5 1 3 7 3 7 4 5 6 3 4 5 8 3 5 6 6 3 3 4 3 9 7 3 5 4 5 5 4 6 5 5 4 6 4 5 5
#  5 3 4 3 4 4 4 6 5 5 5 7 6 6 7 8 7 7 4 2 7 5 6 2 4 2 6 7 5 7 4 6 5 4 3 7 3
#  4 6 3 6 5 8 3 5 4 5 5 7 4 6 4 4 8 5 6 6 4 3 5 2 2 4 5 8 4 5 5 3 4 5 5 7 3
#  8 5 5 2 6 3 4 5 6 5 4 7 5 4 3 4 8 7 6 6 4 5 6 5 2 4 3 4 6 6 4 7 7 8 5 4 3
#  5 6 4 7 7 5 4 3 4 4 5 5 2 6 6 5 4 7 8 6 8 7 5 6 5 6 4 6 4 5 4 8 5 6 6 5 6
#  5 7 4 4 3 4 6 6 2 7 3 5 4 4 6 5 5 5 7 8 5 6 6 5 2 5 6 4 4 6 5 8 5 2 6 4 4
#  6 4 6 5 2 2 3 4 3 6 4 0 5 9 6 6 3 7 5 6 4 7 8 4 1 7 4 5 7 4 3 5 3 2 5 5 4
#  5 6 6 4 7 4 7 3 5 5 6 5 4 6 6 8 3 5 2 2 4 7 5 6 4 6 6 6 3 6 4 6 3 2 5 4 4
#  4 3 5 6 6 6 8 5 6 4 3 4 6 6 6 4 6 6 3 7 7 7 5 6 3 4 7 3 3 6 2 4 4 7 7 4 3
#  6 4 6 4 5 5 3 6 4 5 4 2 8 6 4 2 5 3 4 5 3 4 5 6 5 7 6 6 6 3 8 4 6 3 8 5 8
#  4 6 5 7 6 5 4 7 4 3 4 5 8 6 4 5 8 3 0 4 5 5 4 4 4 4 1 5 6 6 5 6 2 4 7 7 2
#  4 5 7 5 4 6 3 2 7 5 8 6 6 4 5 4 5 5 4 7 4 6 4 6 6 7 4 3 3 3 6 3 6 2 6 4 5
#  3 6 6 5 4 7 4 5 5 7 4 8 3 8 2 5 7 2 3 4 3 5 5 3 5 3 8 8 9 5 6 6 5 6 4 6 5
#  4 2 4 5 3 3 4 3 4 5 2 5 8 6 3 6 4 2 7 3 5 2 6 5 4 5 3 4 7 1 4 5 7 7 5 3 5
#  3 3 7 7 5 3 2 0 5 5 3 6 6 0 6 6 1 7 3 6 4 7 6 8 4 7 5 9 6 5 5 5 7 4 4 5 3
#  1]

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
plt.show()
# Out:
# C:\Users\aarya\AppData\Local\Temp\ipykernel_17112\2410585992.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %%
x = random.poisson(lam=2, size=10)
print(x)
# Out:
# [2 2 2 5 1 1 2 0 1 7]

# %%
sns.distplot(random.poisson(lam=2, size=1000), kde=False)
plt.show()
# Out:
# C:\Users\aarya\AppData\Local\Temp\ipykernel_17112\3521096022.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)
